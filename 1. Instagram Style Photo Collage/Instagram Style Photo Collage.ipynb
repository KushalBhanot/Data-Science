# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
top_left = cv2.imread("./ImageCollage dataset/top_left.jpg")
rgb1 = cv2.cvtColor(top_left, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb1)

# %%
top_right = cv2.imread("./ImageCollage dataset/top_right.jpg")
rgb2 = cv2.cvtColor(top_right, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb2)

# %%
center = cv2.imread("./ImageCollage dataset/center.jpeg")
rgb3 = cv2.cvtColor(center, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb3)

# %%
bottom_left = cv2.imread("./ImageCollage dataset/bottom_left.jpg")
rgb4 = cv2.cvtColor(bottom_left, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb4)

# %%
bottom_right = cv2.imread("./ImageCollage dataset/bottom_right.jpg")
rgb5 = cv2.cvtColor(bottom_right, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb5)

# %%
rgb1 = cv2.resize(rgb1, (200,200))
rgb1.shape
# Out:
# (200, 200, 3)

# %%
rgb2 = cv2.resize(rgb2, (200,200))
rgb2.shape
# Out:
# (200, 200, 3)

# %%
rgb3 = cv2.resize(rgb3, (200,200))
rgb3.shape
# Out:
# (200, 200, 3)

# %%
rgb4 = cv2.resize(rgb4, (200,200))
rgb4.shape
# Out:
# (200, 200, 3)

# %%
rgb5 = cv2.resize(rgb5, (200,200))
rgb5.shape
# Out:
# (200, 200, 3)

# %%
col1 = np.vstack([rgb1, rgb4])
plt.imshow(col1)

# %%
col2 = np.vstack([rgb2, rgb5])
plt.imshow(col2)

# %%
collage1 = np.hstack([col1, col2])
plt.imshow(collage1)
plt.show()
