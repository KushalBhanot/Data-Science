# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/Users/kushal/Documents/Pictures/Profile Picture.jpg')
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
print(img.shape)
# Out:
# (1080, 1080, 3)

# %%
plt.imshow(rgb_image)

plt.show()

# %%
crop_image = rgb_image[ 0:500 ,300:850, :]
plt.imshow(crop_image)
plt.show()

# %%
crop_image.shape
# Out:
# (500, 550, 3)

# %%
total_pixels = crop_image.shape[0] * crop_image.shape[1]
print(total_pixels)
# Out:
# 275000

# %% [markdown]
# # Resizing the image

# %%
crop_img = cv2.resize(crop_image, (100, 100))

# %%
plt.imshow(crop_image)
plt.title("Kushal" + str(crop_image.shape))
plt.show()
